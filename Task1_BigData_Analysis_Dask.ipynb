# %% [markdown]
# <a href="https://colab.research.google.com/github/manikandan1908/CODTECH-TASK-1-TO-4/blob/main/Task1_BigData_Analysis_Dask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install dask

# %%
import os
os.listdir()
# Out:
# ['.config', 'large_sales_data.csv.csv', 'sample_data']

# %%
import dask.dataframe as dd
import matplotlib.pyplot as plt

df = dd.read_csv("large_sales_data.csv.csv")

print("Total Rows:", df.shape[0].compute())

sales_by_category = df.groupby("Category")["Sales"].sum().compute()
sales_by_category.plot(kind='bar')
plt.show()
# Out:
# Total Rows: 50000
