# %% [markdown]
# <a href="https://colab.research.google.com/github/manikandan1908/CODTECH-TASK-1-TO-4/blob/main/TASK_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn nltk

# %%
import pandas as pd

# Sample dataset
data = {
    "Review": [
        "I love this product, it's amazing!",
        "Terrible experience, will not buy again.",
        "Absolutely fantastic, highly recommend!",
        "Worst purchase ever, very disappointed.",
        "Good quality, satisfied with the product.",
        "Not worth the money, very bad."
    ],
    "Sentiment": ["Positive", "Negative", "Positive", "Negative", "Positive", "Negative"]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                                       Review Sentiment
# 0         I love this product, it's amazing!  Positive
# 1   Terrible experience, will not buy again.  Negative
# 2    Absolutely fantastic, highly recommend!  Positive
# 3    Worst purchase ever, very disappointed.  Negative
# 4  Good quality, satisfied with the product.  Positive

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = text.lower()                  # lowercase
    text = ' '.join([w for w in text.split() if w not in stop_words])
    return text

df['Clean_Review'] = df['Review'].apply(clean_text)
df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                       Review Sentiment  \
# 0         I love this product, it's amazing!  Positive
# 1   Terrible experience, will not buy again.  Negative
# 2    Absolutely fantastic, highly recommend!  Positive
# 3    Worst purchase ever, very disappointed.  Negative
# 4  Good quality, satisfied with the product.  Positive
#
#                             Clean_Review
# 0                   love product amazing
# 1                terrible experience buy
# 2  absolutely fantastic highly recommend
# 3       worst purchase ever disappointed
# 4         good quality satisfied product

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix

# Features and target
X = df['Clean_Review']
y = df['Sentiment']

# Convert text to numeric features
vectorizer = CountVectorizer()
X_vect = vectorizer.fit_transform(X)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_vect, y, test_size=0.2, random_state=42)

# Train model
model = MultinomialNB()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluation
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative       1.00      1.00      1.00         1
#     Positive       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# Confusion Matrix:
#  [[1 0]
#  [0 1]]

# %%
df.to_csv("cleaned_reviews.csv", index=False)
